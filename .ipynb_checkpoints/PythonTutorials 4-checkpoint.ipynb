# %% [markdown]
# # Pandas

# %%
from pandas import *
import pandas as pd
data=pd.Series([1.3,2.4,3.2,4.1]) #lzam gwaha list or tuples
print(data)
print(data.index)
print("------------")
data=pd.Series((1,2,3,4)) #lzam gwaha list or tuples
print(data)
print(data.values)
print(data.index)
print(data.keys)#default lw print dat bs
print(data.describe()) #bynata7sa2ya
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

print(data.agg(['max','min','sum','mean','std']))

print(data[1])
print(data[1:3])
print(data[1:3:2])
print("--------------")
data1 = pd.Series([1,2,3,4], index=['a', 'b', 'c', 'd']) #index elii hwa key

data2 = pd.Series({'a':1,'b':2,'c':3,'d':4})
#hya hya
print(data1)
print(data2)
print("--------------")
data1 = pd.Series([1,2,3,4], index=['a', 'b', 'c', 'd'])

data2 = pd.Series({'a':1,'b':2,'c':3,'d':4})

print(data1['a'])
print(data2['b'])
x = pd.Index([2,3,5,7,11])#a3ml list

print(x)
print("---------------")
a = pd.Index([1, 3, 5, 7, 9])
b = pd.Index([2, 3, 5, 7, 11])

print(a)
print(b)
print(a & b)#mwgod fe a w b fe nfs l wa2t
print(a | b)
print(a ^ b)#hat rkam fe a w b ma3da l mtkrara
# Out:
# 0    1.3
# 1    2.4
# 2    3.2
# 3    4.1
# dtype: float64
# RangeIndex(start=0, stop=4, step=1)
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# [1 2 3 4]
# RangeIndex(start=0, stop=4, step=1)
# <bound method Series.keys of 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64>
# count    4.000000
# mean     2.500000
# std      1.290994
# min      1.000000
# 25%      1.750000
# 50%      2.500000
# 75%      3.250000
# max      4.000000
# dtype: float64
# max      9.000000
# min      2.000000
# sum     59.000000
# mean     5.363636
# std      2.292280
# dtype: float64
# 6
# 1    6
# 2    9
# dtype: int64
# 1    6
# dtype: int64
# --------------
# a    1
# b    2
# c    3
# d    4
# dtype: int64
# a    1
# b    2
# c    3
# d    4
# dtype: int64
# --------------
# 1
# 2
# Int64Index([2, 3, 5, 7, 11], dtype='int64')
# ---------------
# Int64Index([1, 3, 5, 7, 9], dtype='int64')
# Int64Index([2, 3, 5, 7, 11], dtype='int64')
# Int64Index([3, 5, 7], dtype='int64')
# Int64Index([1, 2, 3, 5, 7, 9, 11], dtype='int64')
# Int64Index([1, 2, 9, 11], dtype='int64')

# %%
import pandas as pd
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

#data.plot()
#data.plot(kind='line') 

#data.plot(kind='pie') #kors 
#data.plot(kind='bar') 
#data.plot(kind='barh')  
#histogram l 7aga atkrart kam mra
#data.plot(kind='hist')
#data.plot(kind='box')
#data.plot(kind='kde') #mtkrarad eh
data.plot(kind='area')

# %% [markdown]
# # DataFormat

# %%
myarray = np.array([[6,9,8,5,4,2],[0,2,5,6,3,9],
                    [8,5,4,1,2,3],[6,9,8,5,4,2],
                    [0,5,3,6,9,8],[8,7,4,5,2,3]])

rownames = ['a', 'b','c','d','e','f']
colnames = ['one', 'two', 'three','four','five','six']

df = pd.DataFrame(myarray, index=rownames, columns=colnames)

print(df)
print("--------------")
#tre2a tanya
w = pd.Series({'a':1 ,'b':2 ,'c':3 ,'d':4 ,'e':5})
x = pd.Series({'a':6 ,'b':7 ,'c':8 ,'d':9 ,'e':10})
y = pd.Series({'a':11 ,'b':12 ,'c':13 ,'d':14 ,'e':15})
z = pd.Series({'a':16 ,'b':17 ,'c':18 ,'d':19 ,'e':20})


grades = pd.DataFrame({'Math':w,'Physics':x,'French':y,'Chemistry':z})

print(grades)
print(grades['Chemistry'])
print(grades.T)#transpse
print(grades.keys())
print(grades.values)
print("--------")#as2ala
print('Math' in grades.keys())
print('math' in grades.keys())
print(12 in grades.values)
print(55 in grades.values)
print("----------")
print(grades.stack()) #yfokha kol wa7ed lwa7do
print("------------")
print(grades.iloc[:3, :2])#location b index
print(grades.loc['b':'c', 'Math':]) #b esm
print(grades.loc[grades.Math >3]) #aktab gwa condition
print(grades.loc[grades.Math >3,['French' ,'Math']]) #b condition bs french w math bs
print(grades.columns)
print(grades.sort_values(['Math'],ascending= False))
print(grades.sort_values(['French'],ascending= True))
print(grades.max())
print(grades.min())
print(grades.mean())
print(grades.std())
print("------------")
#kolkema
print(grades['Math'].max())
print(grades['French'].min())
print(grades['Physics'].mean())
print(grades['Chemistry'].std())
# Out:
#    one  two  three  four  five  six
# a    6    9      8     5     4    2
# b    0    2      5     6     3    9
# c    8    5      4     1     2    3
# d    6    9      8     5     4    2
# e    0    5      3     6     9    8
# f    8    7      4     5     2    3
# --------------
#    Math  Physics  French  Chemistry
# a     1        6      11         16
# b     2        7      12         17
# c     3        8      13         18
# d     4        9      14         19
# e     5       10      15         20
# a    16
# b    17
# c    18
# d    19
# e    20
# Name: Chemistry, dtype: int64
#             a   b   c   d   e
# Math        1   2   3   4   5
# Physics     6   7   8   9  10
# French     11  12  13  14  15
# Chemistry  16  17  18  19  20
# Index(['Math', 'Physics', 'French', 'Chemistry'], dtype='object')
# [[ 1  6 11 16]
#  [ 2  7 12 17]
#  [ 3  8 13 18]
#  [ 4  9 14 19]
#  [ 5 10 15 20]]
# --------
# True
# False
# True
# False
# ----------
# a  Math          1
#    Physics       6
#    French       11
#    Chemistry    16
# b  Math          2
#    Physics       7
#    French       12
#    Chemistry    17
# c  Math          3
#    Physics       8
#    French       13
#    Chemistry    18
# d  Math          4
#    Physics       9
#    French       14
#    Chemistry    19
# e  Math          5
#    Physics      10
#    French       15
#    Chemistry    20
# dtype: int64
# ------------
#    Math  Physics
# a     1        6
# b     2        7
# c     3        8
#    Math  Physics  French  Chemistry
# b     2        7      12         17
# c     3        8      13         18
#    Math  Physics  French  Chemistry
# d     4        9      14         19
# e     5       10      15         20
#    French  Math
# d      14     4
# e      15     5
# Index(['Math', 'Physics', 'French', 'Chemistry'], dtype='object')
#    Math  Physics  French  Chemistry
# e     5       10      15         20
# d     4        9      14         19
# c     3        8      13         18
# b     2        7      12         17
# a     1        6      11         16
#    Math  Physics  French  Chemistry
# a     1        6      11         16
# b     2        7      12         17
# c     3        8      13         18
# d     4        9      14         19
# e     5       10      15         20

# %%
s="merna"
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e0de9d9dd465> in <module>
#       1 s="merna"
# ----> 2 s[0]='f'
#       3 print(s)
#
# TypeError: 'str' object does not support item assignment
